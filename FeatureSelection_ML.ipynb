# %% [markdown]
# <a href="https://colab.research.google.com/github/roshan07273/Machine_learning_Algos/blob/main/FeatureSelection_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **FORWARD FEATURE SELECTION:**
# 1. It start with a single feature only ,
#  and progressively it will add each feature in a time.
# 2. Here the model will train on each feature separatly.
# 3. The feature with the best performance is selected
# 4. The process will be repeated until a significent increase in the performance of the model.

# %%
pip install mlxtend

# %%
import pandas as pd
df = pd.read_csv('/content/iris.csv')

# %%
df.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lc = LabelEncoder()

# %%
df['Species'] = lc.fit_transform(df['Species'])

# %%
df.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0
# 4   5            5.0           3.6            1.4           0.2        0

# %%
x = df.iloc[: , 0:4]

# %%
x.shape
# Out:
# (150, 4)

# %%
x.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm
# 0   1            5.1           3.5            1.4
# 1   2            4.9           3.0            1.4
# 2   3            4.7           3.2            1.3
# 3   4            4.6           3.1            1.5
# 4   5            5.0           3.6            1.4

# %%
from sklearn.model_selection import train_test_split

# %%
x_test , y_test , x_train , y_train = train_test_split(x,y,test_size = 0.2)

# %%
x_train.shape

# %%
x_test.shape

# %%
from mlxtend.feature_selection import SequentialFeatureSelector

# %%
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# **FORWARD SELECTION METHOD USING RANDOM FOREST**
#  //k_feature=(1,4)

# %%
forward_feature = SequentialFeatureSelector(RandomForestClassifier(n_jobs = -1),
                                            k_features=2,
                                             forward=True,
                                             cv=5,
                                             scoring='accuracy',
                                             verbose=2
                                            ).fit(x_train , y_train)

# %%
forward_feature.k_feature_names_

# %%
forward_feature.k_feature_idx_

# %% [markdown]
# BACKWARD SELECTION USING RANDOM

# %%
backward_feature=SequentialFeatureSelector(RandomForestClassifier(n_jobs = -1),
                                            k_features=2,
                                             forward=False,
                                             cv=5,
                                             scoring='accuracy',
                                             verbose=2
                                            ).fit(x_train , y_train)
